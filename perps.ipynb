# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import csv
import statsmodels.api as sm

import matplotlib.pyplot as plt
from seaborn import histplot, scatterplot, heatmap

# %%
perps = pd.read_csv('data/names_of_perpetrators.csv')
perps.shape
# Out:
# (397, 30)

# %%
perps.head()
# Out:
#    person_ID   first_name last_name           full_name  \
# 0          1    Zacharias  Moussaui  Zacharias Moussaui
# 1          2      Richard      Reid        Richard Reid
# 2          3  John Walker     Lindh   John Walker Lindh
# 3          4          Ali  al-Marri        Ali al-Marri
# 4          5        Imran   Mandhai       Imran Mandhai
#
#                  headshot                                    headshot_credit  \
# 0  zacarias_moussaoui.jpg                    U.S. government / public domain
# 1        richard_reid.jpg                    U.S. government / public domain
# 2   john_walker_lindh.jpg  Alexandria County Sheriff's Department / publi...
# 3                     NaN                                                NaN
# 4       imran_mandhai.png  U.S. Immigration and Customs Enforcement / pub...
#
#   gender   age inv_informant inv_public_tip  ... state_charged_2  \
# 0   Male  33.0            No            Yes  ...             NaN
# ...

# %%
perps.tail()
# Out:
#      person_ID         first_name   last_name                  full_name  \
# 392        395          Balwinder       Singh            Balwinder Singh
# 393        396      Samy Mohammed  el-Goarany   Samy Mohammed El-Goarany
# 394        397  Saynab Abdirashid     Hussein  Saynab Abdirashid Hussein
# 395        398      Lionel Nelson    Williams     Lionel Nelson Williams
# 396        399               Noor      Salman                Noor Salman
#
#     headshot headshot_credit  gender   age inv_informant inv_public_tip  ...  \
# 392      NaN             NaN    Male  39.0            No             No  ...
# 393      NaN             NaN    Male  24.0            No             No  ...
# 394      NaN             NaN  Female  24.0            No             No  ...
# 395      NaN             NaN    Male  26.0           Yes            Yes  ...
# 396      NaN             NaN  Female  30.0            No             No  ...
#
# ...

# %%
perps.describe
# Out:
# <bound method NDFrame.describe of      person_ID         first_name   last_name                  full_name  \
# 0            1          Zacharias    Moussaui         Zacharias Moussaui
# 1            2            Richard        Reid               Richard Reid
# 2            3        John Walker       Lindh          John Walker Lindh
# 3            4                Ali    al-Marri               Ali al-Marri
# 4            5              Imran     Mandhai              Imran Mandhai
# ..         ...                ...         ...                        ...
# 392        395          Balwinder       Singh            Balwinder Singh
# 393        396      Samy Mohammed  el-Goarany   Samy Mohammed El-Goarany
# 394        397  Saynab Abdirashid     Hussein  Saynab Abdirashid Hussein
# 395        398      Lionel Nelson    Williams     Lionel Nelson Williams
# 396        399               Noor      Salman                Noor Salman
#
#                    headshot  \
# ...

# %%
plt.figure(figsize = (12, 7))
sns.heatmap((perps).corr(), annot = True, linewidths=.5, vmin = -1, vmax = 1)
plt.title('Correlation Heatmap', fontsize = 15)
plt.show()
# Out:
# C:\Users\monke\AppData\Local\Temp\ipykernel_67168\464006447.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap((perps).corr(), annot = True, linewidths=.5, vmin = -1, vmax = 1)

# %%
# created a pair plot to identify relationships between variables
sns.pairplot(data=perps, corner=True)
